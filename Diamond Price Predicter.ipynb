# %% [markdown]
# # Diamond Price Investigation

# %%
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns
import scipy.stats as stats
import numpy as np

# %%
df = pd.read_csv('diamonds.csv')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df_cat = df[['cut','color','clarity']]
df_num = df[['carat','depth','table','price','x','y','z']]

# %%
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
for i in df_num.columns:
    plt.boxplot(df_num[i])
    plt.title(i)
    plt.show()

# %%
mean_of_num = df_num.mean()
mean_of_num
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
medianan_of_num = df_num.median()
medianan_of_num
# Out:
# carat       0.70
# depth      61.80
# table      57.00
# price    2401.00
# x           5.70
# y           5.71
# z           3.53
# dtype: float64

# %%
SD_of_num = np.std(df_num)
SD_of_num
# Out:
# carat       0.474007
# depth       1.432608
# table       2.234470
# price    3989.402758
# x           1.121750
# y           1.142124
# z           0.705692
# dtype: float64

# %%
print(df_num.corr())
sns.heatmap(df_num.corr())
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000
# <Axes: >

# %%
plt.plot(df.carat, df.price,'x')
plt.title("price and carat")
plt.xlabel("carat")
plt.ylabel("price")
plt.show()

# %%
plt.plot(df.x, df.price,'x')
plt.title("price and x")
plt.xlabel("x")
plt.ylabel("price")
plt.show()

# %%
plt.plot(df.y, df.price,'x')
plt.title("price and y")
plt.xlabel("y")
plt.ylabel("price")
plt.show()

# %%
plt.plot(df.z, df.price,'x')
plt.title("price and z")
plt.xlabel("z")
plt.ylabel("price")
plt.show()

# %%
plt.bar(df.color, df.price)
plt.show()

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df_color = df['color'].value_counts() 
print(df_color)
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
plt.bar(data[0],data[1])
plt.show()

# %%
df_clarity = df['clarity'].value_counts() 
print(df_clarity)
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
# Define the bin edges to create 5 groups
bin_edges = [0, 5000, 10000, 15000, 20000]

# Create a new column 'Group' to store the group labels
df['Group'] = pd.cut(df['price'], bins=bin_edges, labels=['0 - 5000', '5000 - 10000', '10000-15000', '15000 - 20000'])

# Group and count the data
grouped_data = df.groupby('Group').count()

# Display the grouped data table
print(grouped_data)
# Out:
#                carat    cut  color  clarity  depth  table  price      x  \
# Group
# 0 - 5000       39226  39226  39226    39226  39226  39226  39226  39226
# 5000 - 10000    9492   9492   9492     9492   9492   9492   9492   9492
# 10000-15000     3567   3567   3567     3567   3567   3567   3567   3567
# 15000 - 20000   1655   1655   1655     1655   1655   1655   1655   1655
#
#                    y      z
# Group
# 0 - 5000       39226  39226
# 5000 - 10000    9492   9492
# 10000-15000     3567   3567
# 15000 - 20000   1655   1655

# %%
cross_tab = pd.crosstab(df['clarity'], df['color'])

# Display the two-way table
print(cross_tab)
# Out:
# color       D     E     F     G     H     I    J
# clarity
# I1         42   102   143   150   162    92   50
# IF         73   158   385   681   299   143   51
# SI1      2083  2426  2131  1976  2275  1424  750
# SI2      1370  1713  1609  1548  1563   912  479
# VS1       705  1281  1364  2148  1169   962  542
# VS2      1697  2470  2201  2347  1643  1169  731
# VVS1      252   656   734   999   585   355   74
# VVS2      553   991   975  1443   608   365  131

# %%
df_I1 = df[(df['clarity'] == "I1")]

# %%
#plt.hist(df_I1['price'])
#plt.title("price of I1")
#plt.show()

# %%
#Clarity = ['I1','IF','SI1','SI2','VS1','VS2','VVS1','VVS2']
#for i in Clarity:
    plt.hist(df[(df['clarity'] == i)]['price'])
    plt.title("Price of " + i)
    plt.show()
# Out:
#   Cell In[57], line 3
#     plt.hist(df[(df['clarity'] == i)]['price'])
#     ^
# IndentationError: unexpected indent

# %%
def outliers (column):
    q3,q1 = np.percentile(df[column],[75,25])
    iqr = q3 - q1
    lowerOutlier = q1 - 1.5*iqr
    upperOutlier = q3 + 1.5*iqr
    return (lowerOutlier,upperOutlier)

# %%
dimensions = ['x','y','z','price']
for i in dimensions:
    df_outliers_removed = df[(df[i] < outliers(i)[1] ) & (df[i] > outliers(i)[0])]

# %%
#Clarity = ['I1','IF','SI1','SI2','VS1','VS2','VVS1','VVS2']
#for i in Clarity:
    plt.hist(df_outliers_removed[(df_outliers_removed['clarity'] == i)]['price'])
    plt.title("Price of " + i)
    plt.show()
# Out:
#   Cell In[55], line 3
#     plt.hist(df_outliers_removed[(df_outliers_removed['clarity'] == i)]['price'])
#     ^
# IndentationError: unexpected indent

# %%
#Clarity = ['I1','IF','SI1','SI2','VS1','VS2','VVS1','VVS2']
#for i in Clarity:
    plt.boxplot(df_outliers_removed[(df_outliers_removed['clarity'] == i)]['price'])
    plt.title("Price of " + i)
    plt.show()
# Out:
#   Cell In[54], line 3
#     plt.boxplot(df_outliers_removed[(df_outliers_removed['clarity'] == i)]['price'])
#     ^
# IndentationError: unexpected indent

# %%
dimensions = ['x','y','z','price']
for i in dimensions:
    df_outliers_removed_again = df_outliers_removed[(df_outliers_removed[i] < outliers(i)[1] ) & (df_outliers_removed[i] > outliers(i)[0])]

# %%
Clarity = ['I1','IF','SI1','SI2','VS1','VS2','VVS1','VVS2']
for i in Clarity:
    plt.boxplot(df_outliers_removed_again[(df_outliers_removed_again['clarity'] == i)]['price'])
    plt.title("Price of " + i)
    plt.show()

# %%
sns.boxplot(data=df_outliers_removed_again,x='price',y='clarity')
# Out:
# <Axes: xlabel='price', ylabel='clarity'>

# %%
sns.boxplot(data=df_outliers_removed_again,x='price',y='color')
# Out:
# <Axes: xlabel='price', ylabel='color'>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

diamonds_data = pd.read_csv('diamonds.csv')
y = diamonds_data.price
feature_columns = ['carat', 'x', 'y', 'z']
X = diamonds_data[feature_columns]

# Specify Model
diamonds_model = DecisionTreeRegressor()
# Fit Model
diamonds_model.fit(X, y)

print("First in-sample predictions:", diamonds_model.predict(X.head()))
print("Actual target values for those diamonds:", y.head().tolist())
# Out:
# First in-sample predictions: [326. 326. 327. 334. 335.]
# Actual target values for those diamonds: [326, 326, 327, 334, 335]

# %%
# Import the train_test_split function and uncomment
# from _ import _
from sklearn.model_selection import train_test_split

# fill in and uncomment
# train_X, val_X, train_y, val_y = ____
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)

# %%
# You imported DecisionTreeRegressor in your last exercise
# and that code has been copied to the setup code above. So, no need to
# import it again

# Specify the model
diamonds_model = DecisionTreeRegressor(random_state=1)

# Fit iowa_model with the training data.
diamonds_model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
# Predict with all validation observations

val_predictions = diamonds_model.predict(val_X)

# %%
# print the top few validation predictions
print(val_predictions[0:6])
# print the top few actual prices from validation data
print(val_y[0:6])
# Out:
# [ 631. 8279. 1991.  567. 6932.  984.]
# 2714      564
# 14653    5914
# 52760    2562
# 48658     537
# 14812    5964
# 37498     984
# Name: price, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error
val_mae = mean_absolute_error(val_y, val_predictions)

# uncomment following line to see the validation_mae
print(val_mae)
# Out:
# 1055.4579083942876
